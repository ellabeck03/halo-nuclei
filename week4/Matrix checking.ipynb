# %%
import numpy as np

l0_n_matrix = np.genfromtxt('s_state_n_matrix.csv', delimiter=',')
l0_h_matrix = np.genfromtxt('s_state_h_matrix.csv', delimiter=',')
l1_n_matrix = np.genfromtxt('p_state_n_matrix.csv', delimiter=',')
l1_h_matrix = np.genfromtxt('p_state_h_matrix.csv', delimiter=',')
l2_n_matrix = np.genfromtxt('d_state_n_matrix.csv', delimiter=',')
l2_h_matrix = np.genfromtxt('d_state_h_matrix.csv', delimiter=',')

l01_n_matrix_comparison = np.zeros(shape=(30, 30))
for i in range(30):
    for j in range(30):
        l01_n_matrix_comparison[i, j] = l0_n_matrix[i, j] / l1_n_matrix[i, j]
l02_n_matrix_comparison = np.zeros(shape=(30, 30))
for i in range(30):
    for j in range(30):
        l02_n_matrix_comparison[i, j] = l0_n_matrix[i, j] / l2_n_matrix[i, j]
l12_n_matrix_comparison = np.zeros(shape=(30, 30))
for i in range(30):
    for j in range(30):
        l12_n_matrix_comparison[i, j] = l1_n_matrix[i, j] / l2_n_matrix[i, j]
print(l01_n_matrix_comparison)
# Out:
# [[1.00000000e+00 1.06066017e+00 1.25000000e+00 1.59099026e+00
#   2.12500000e+00 2.91681547e+00 4.06250000e+00 5.70104842e+00
#   8.03125000e+00 1.13358056e+01 1.60156250e+01 2.26384655e+01
#   3.20078125e+01 4.52603583e+01 6.40039062e+01 9.05124301e+01
#   1.28001953e+02 1.81020717e+02 2.56000977e+02 3.62039363e+02
#   5.12000488e+02 7.24077689e+02 1.02400024e+03 1.44815486e+03
#   2.04800012e+03 2.89630946e+03 4.09600006e+03 5.79261879e+03
#   8.19200003e+03 1.15852375e+04]
#  [1.06066017e+00 1.00000000e+00 1.06066017e+00 1.25000000e+00
#   1.59099026e+00 2.12500000e+00 2.91681547e+00 4.06250000e+00
#   5.70104842e+00 8.03125000e+00 1.13358056e+01 1.60156250e+01
#   2.26384655e+01 3.20078125e+01 4.52603583e+01 6.40039063e+01
#   9.05124301e+01 1.28001953e+02 1.81020717e+02 2.56000977e+02
#   3.62039363e+02 5.12000488e+02 7.24077689e+02 1.02400024e+03
#   1.44815486e+03 2.04800012e+03 2.89630946e+03 4.09600006e+03
#   5.79261879e+03 8.19200003e+03]
# ...

# %%
print(l02_n_matrix_comparison)
# Out:
