# %%
import numpy as np
import matplotlib.pyplot as plt

be_rms_vals = [2.31, 2.38, 2.30, 2.91, 2.59, 3.1]
be_rms_uncert = [0.02, 0.01, 0.02, 0.05, 0.06, 0.15]
A_vals = [7, 9, 10, 11, 12, 14]

fig = plt.figure()
    #figsize=(15, 10), layout='constrained')
ax = fig.add_subplot()

ax.errorbar(A_vals, be_rms_vals, yerr=be_rms_uncert, linestyle=':', fmt='x', capsize=5, label='Tanihata Data', color = 'mediumblue')
ax.scatter(11, 3.11, label='Predicted r.m.s from model', marker='x', color='red', s=100)
plt.legend()
plt.show()
