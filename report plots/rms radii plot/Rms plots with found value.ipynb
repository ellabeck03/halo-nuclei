# %%
import numpy as np
import matplotlib.pyplot as plt

be_rms_vals = [2.31, 2.38, 2.30, 2.91, 2.59, 3.1]
be_rms_uncert = [0.02, 0.01, 0.02, 0.05, 0.06, 0.15]
A_vals = [7, 9, 10, 11, 12, 14]

fig = plt.figure()
    #figsize=(15, 10), layout='constrained')
ax = fig.add_subplot()

ax.errorbar(A_vals, be_rms_vals, yerr=be_rms_uncert, linestyle=':', fmt='x', capsize=5, label='Tanihata Data', color = 'darkblue')
ax.scatter(11, 2.9729611785309027, label='Predicted r.m.s from model', marker='x', color='firebrick', s=100)
ax.set_xlabel('A')
ax.set_ylabel('r.m.s radius')
plt.savefig('rms_plot.png')
plt.legend()
plt.show()
